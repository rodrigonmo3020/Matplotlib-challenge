# %% [markdown]
# # Pymaceuticals Inc.
# Analysis
# - Add your analysis here.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combine the data into a single DataFrame
mouse_study_complete = pd.merge(study_results,mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])
# Display the data table for preview
mouse_study_complete
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Checking the number of mice.
len(mouse_study_complete['Mouse ID'].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.


# mouse_study_complete_a = mouse_study_complete.drop_duplicates(subset=['Mouse ID','Timepoint'], keep='last', inplace=False)
# mouse_study_complete_a
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# mouse_study_loc = mouse_study_complete_a.loc[mouse_study_complete_a['Mouse ID']== 'g989', :]
# mouse_study_loc
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 137      g989          0           45.000000                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# 1380     g989         30           59.082294                 1     Propriva
# 1592     g989         35           62.570880                 2     Propriva
#
#          Sex  Age_months  Weight (g)
# 137   Female          21          26
# 360   Female          21          26
# 681   Female          21          26
# 869   Female          21          26
# 1111  Female          21          26
# 1195  Female          21          26
# ...

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
duplicate_mice = mouse_study_complete.loc[mouse_study_complete.duplicated(subset=['Mouse ID', 'Timepoint']), 'Mouse ID'].unique()
duplicate_mice
# Out:
# array(['g989'], dtype=object)

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

mouse_study_clean = mouse_study_complete[mouse_study_complete['Mouse ID'].isin(duplicate_mice)==False]
mouse_study_clean.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(mouse_study_clean['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# # Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.

mean_tumor = mouse_study_clean['Tumor Volume (mm3)'].groupby(mouse_study_clean['Drug Regimen']).mean()
median_tumor = mouse_study_clean['Tumor Volume (mm3)'].groupby(mouse_study_clean['Drug Regimen']).median()
variance_tumor = mouse_study_clean['Tumor Volume (mm3)'].groupby(mouse_study_clean['Drug Regimen']).var()
standard_tumor = mouse_study_clean['Tumor Volume (mm3)'].groupby(mouse_study_clean['Drug Regimen']).std()
SEM_tumor = mouse_study_clean['Tumor Volume (mm3)'].groupby(mouse_study_clean['Drug Regimen']).sem()

summary_stats = pd.DataFrame({'Mean Tumor Volume': mean_tumor,
                             'Median Tumor Volume': median_tumor,
                             'Tumor Volume Variance': variance_tumor,
                             'Tumor Volume Std. Dev.': standard_tumor,
                             'Tumor Volume Std. Err.': SEM_tumor
                             })

summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line

summary_stats = mouse_study_clean.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['mean', 'median', 'var', 'std', 'sem'])
summary_stats
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# # Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each
# drug regimen using Pandas.

drug_reg = mouse_study_clean['Drug Regimen'].value_counts()
drug_reg
# Out:
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Stelasyn     181
# Placebo      181
# Infubinol    178
# Ceftamin     178
# Propriva     148
# Name: Drug Regimen, dtype: int64

# %%
plot_p = drug_reg.plot.bar(color='b')
plt.xlabel("Drug Regimen")
plt.ylabel("# of Observed Mouse Timepoints")
# Out:
# Text(0, 0.5, '# of Observed Mouse Timepoints')

# %%
# Generate a bar plot showing the total number of rows 
# (Mouse ID/Timepoints) for each drug regimen using pyplot.

drugs = ['Capomulin', 'Ramicane', 'Ketapril', 'Naftisol', 'Zoniferol', 'Stelasyn', 
         'Placebo', 'Infubinol', 'Ceftamin', 'Propriva']
mouse_count = [230, 228, 188, 186, 182, 181, 181, 178, 178, 148]
x_axis = np.arange(len(drugs))

plt.bar(x_axis, mouse_count, color='b', align='center')
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, drugs, rotation='vertical')
plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(mouse_count)+10)

plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

sex_count = mouse_study_clean['Sex'].value_counts()
sex_count
# Out:
# Male      958
# Female    922
# Name: Sex, dtype: int64

# %%
sex_count.plot.pie(autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
sex= ['Male', 'Female']
count= [958, 922]
plt.pie(count, labels=sex, autopct="%1.1f%%", shadow=False, startangle=0)
plt.axis("equal")
plt.show()

# %% [markdown]
# # Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse

capomulin_vol = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Capomulin',:]
ramicane_vol = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Ramicane',:]
infubinol_vol = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Infubinol',:]
ceftamin_vol = mouse_study_clean.loc[mouse_study_clean['Drug Regimen'] == 'Ceftamin',:]


capomulin_max= capomulin_vol.groupby('Mouse ID').max()['Timepoint']
capomulin_max_vol = pd.DataFrame(capomulin_max)

ramicane_max= ramicane_vol.groupby('Mouse ID').max()['Timepoint']
ramicane_max_vol = pd.DataFrame(ramicane_max)

infubinol_max= infubinol_vol.groupby('Mouse ID').max()['Timepoint']
infubinol_max_vol = pd.DataFrame(infubinol_max)

ceftamin_max= ceftamin_vol.groupby('Mouse ID').max()['Timepoint']
ceftamin_max_vol = pd.DataFrame(ceftamin_max)

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint

capomulin_merge = pd.merge(capomulin_max_vol, mouse_study_clean, on=("Mouse ID","Timepoint"), how="left")
ramicane_merge = pd.merge(ramicane_max_vol, mouse_study_clean, on=("Mouse ID","Timepoint"),how="left")
infubinol_merge = pd.merge(infubinol_max_vol, mouse_study_clean, on=("Mouse ID","Timepoint"),how="left")
ceftamin_merge = pd.merge(ceftamin_max_vol, mouse_study_clean, on=("Mouse ID","Timepoint"),how="left")
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)

# Create empty list to fill with tumor vol data (for plotting)

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes

    
    # add subset 

    
    # Determine outliers using upper and lower bounds

# %% [markdown]
# # Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

capomulin_line = capomulin_vol.loc[capomulin_vol["Mouse ID"] == "l509",:]
# capomulin_line.head()
x_axis = capomulin_line["Timepoint"]
tum_size = capomulin_line["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()
plt.title('Capomulin treatmeant of mouse l509')
plt.plot(x_axis, tum_size,linewidth=2, markersize=15, color="blue")
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume 
# for the entire Capomulin regimen.

fig1, ax1 = plt.subplots()
avgerage_vol =capomulin_vol.groupby(['Mouse ID']).mean()

marker_size=12
plt.scatter(avgerage_vol['Weight (g)'],avgerage_vol['Tumor Volume (mm3)'], color="blue")
plt.xlabel('Weight (g)',fontsize =11)
plt.ylabel('Averag Tumor Volume (mm3)')
# Out:
# C:\Users\rodri\AppData\Local\Temp\ipykernel_7348\342174855.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avgerage_vol =capomulin_vol.groupby(['Mouse ID']).mean()
# Text(0, 0.5, 'Averag Tumor Volume (mm3)')

# %% [markdown]
# # Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = st.pearsonr(avgerage_vol['Weight (g)'],avgerage_vol['Tumor Volume (mm3)'])
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84

# %%
(slope, intercept, rvalue, pvalue, stderr)= st.linregress(avgerage_vol["Weight (g)"],avgerage_vol["Tumor Volume (mm3)"])
regress_values=avgerage_vol["Weight (g)"]* slope + intercept

plt.scatter(avgerage_vol["Weight (g)"],avgerage_vol["Tumor Volume (mm3)"],color='b')
plt.plot(avgerage_vol["Weight (g)"], regress_values, color='red')
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Weight vs Tumor Volume for Capomulin")
plt.show()
